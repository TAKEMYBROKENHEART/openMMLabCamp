# %%
# !pip install torch
# !pip install torchvision
# !pip install -U openmim
# !mim install mmengine
# !mim install 'mmcv==2.0.0rc3'
# !mim install "mmdet>=3.0.0rc6"
# !pip install opencv-python pillow matplotlib seaborn tqdm pycocotools -i https://pypi.tuna.tsinghua.edu.cn/simple
# Out:
# Looking in indexes: https://mirrors.aliyun.com/pypi/simple/, https://pypi.tuna.tsinghua.edu.cn/simple/, https://pypi.douban.com/simple, https://pypi.mirrors.ustc.edu.cn/simple/
# ...

# %%
# %cd /root/mmpretrain/
# !mim install -e ".[multimodal]"
# Out:
# /root/mmpretrain
# Looking in indexes: https://mirrors.aliyun.com/pypi/simple/, https://pypi.tuna.tsinghua.edu.cn/simple/, https://pypi.douban.com/simple, https://pypi.mirrors.ustc.edu.cn/simple/
# Looking in links: https://download.openmmlab.com/mmcv/dist/cu117/torch1.13.0/index.html
# Obtaining file:///root/mmpretrain
# ...
#      |████████████████████████████████| 42 kB 141 kB/s  eta 0:00:01
# ...
#      |████████████████████████████████| 7.1 MB 6.7 MB/s eta 0:00:01     |██▏                             | 471 kB 5.0 MB/s eta 0:00:02     |██████▌                         | 1.4 MB 5.0 MB/s eta 0:00:02     |████████████                    | 2.6 MB 5.0 MB/s eta 0:00:01     |███████████████████▍            | 4.3 MB 5.0 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 236 kB 7.7 MB/s eta 0:00:01
# ...

# %% [markdown]
# # 安装完成

# %% [markdown]
# ## 测试安装成功与否

# %%
import mmpretrain
print(mmpretrain.__version__)
# Out:
# 1.0.0rc8

# %%
from mmpretrain import get_model,list_models,inference_model
list_models(task='Image Classification',pattern='resnet18')
# Out:
# ['resnet18_8xb16_cifar10', 'resnet18_8xb32_in1k']

# %%
list_models(task='Image Caption',pattern='blip')
# Out:
# ['blip-base_3rdparty_caption', 'blip2-opt2.7b_3rdparty-zeroshot_caption']

# %%
model = get_model('blip-base_3rdparty_caption')
# Out:
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'BertTokenizer'.
# The class this function is called from is 'BlipTokenizer'.

# %%
type(model)
# Out:
# mmpretrain.models.multimodal.blip.blip_caption.BlipCaption

# %%
inference_model(model,'demo/bird.JPEG',show=True)
# Out:
# Inference ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 06/06 23:20:49 - mmengine - WARNING - `Visualizer` backend is not initialized because save_dir is None.
# {'pred_caption': 'needy medicare pick markings markings than rower yuki protestantsuram sis 520 271 diverse once ballast'}

# %%
# !python demo/image_demo.py demo/demo.JPEG resnet18_8xb32_in1k --device cuda:0 --show
# Out:
# Loads checkpoint by http backend from path: https://download.openmmlab.com/mmclassification/v0/resnet/resnet18_8xb32_in1k_20210831-fbbb1da6.pth
# Inference ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:000m
# 06/06 23:30:45 - mmengine - WARNING - `Visualizer` backend is not initialized because save_dir is None.
# {
#   "pred_label": 58,
#   "pred_score": 0.381022185087204,
#   "pred_class": "water snake"
# }

# %%
# !cd /root/mmpretrain/
from mmengine import Config
cfg = Config.fromfile("./cat_dog/resnet18_cat.py")
cfg.model
# Out:
# {'type': 'ImageClassifier',
#  'backbone': {'type': 'ResNet',
#   'depth': 50,
#   'num_stages': 4,
#   'out_indices': (3,),
#   'frozen_stages': -1,
#   'style': 'pytorch'},
#  'neck': {'type': 'GlobalAveragePooling'},
#  'head': {'type': 'LinearClsHead',
#   'num_classes': 2,
#   'in_channels': 2048,
#   'loss': {'type': 'CrossEntropyLoss', 'loss_weight': 1.0},
#   'topk': (1, 5)},
#  'init_cfg': {'type': 'Pretrained',
#   'checkpoint': 'https://download.openmmlab.com/mmclassification/v0/resnet/resnet18_8xb32_in1k_20210831-fbbb1da6.pth'}}

# %%
cfg.train_dataloader
# Out:
# {'batch_size': 32,
#  'num_workers': 5,
#  'dataset': {'type': 'ImageNet',
#   'data_root': '/root/mmpretrain/dataset/cats_dogs_dataset/training_set',
#   'pipeline': [{'type': 'LoadImageFromFile'},
#    {'type': 'RandomResizedCrop', 'scale': 224},
#    {'type': 'RandomFlip', 'prob': 0.5, 'direction': 'horizontal'},
#    {'type': 'PackInputs'}]},
#  'sampler': {'type': 'DefaultSampler', 'shuffle': True},
#  'persistent_workers': True}

# %%
# !ls
# Out:
# CITATION.cff	 cat_dog  mmpretrain	       resources
# CONTRIBUTING.md  configs  mmpretrain.egg-info  setup.cfg
# LICENSE		 dataset  model-index.yml      setup.py
# MANIFEST.in	 demo	  projects	       tests
# README.md	 docker   requirements	       tools
# README_zh-CN.md  docs	  requirements.txt

# %% [markdown]
# # 自定义的训练模型

# %%
# %cd /root/mmpretrain/cat_dog/
# !mim train mmpretrain /root/mmpretrain/cat_dog/resnet18_cat.py --work-dir=./exp
# Out:
# /root/mmpretrain/cat_dog
# Training command is /opt/conda/bin/python /root/mmpretrain/mmpretrain/.mim/tools/train.py /root/mmpretrain/cat_dog/resnet18_cat.py --launcher none --work-dir=./exp.
# 06/07 00:50:01 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.7.6 (default, Jan  8 2020, 19:59:22) [GCC 7.3.0]
#     CUDA available: True
#     numpy_random_seed: 1173709382
#     GPU 0: Tesla V100S-PCIE-32GB
#     CUDA_HOME: /usr/local/cuda
#     NVCC: Cuda compilation tools, release 10.1, V10.1.24
#     GCC: gcc (Ubuntu 7.5.0-3ubuntu1~18.04) 7.5.0
#     PyTorch: 1.13.1+cu117
#     PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201402
#   - Intel(R) oneAPI Math Kernel Library Version 2021.4-Product Build 20210904 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v2.6.0 (Git Hash 52b5f107dd9cf10910aaa19cb47f3abf9b349815)
# ...

# %% [markdown]
# # 划分数据集

# %%
# !mv --help
# Out:
# Usage: mv [OPTION]... [-T] SOURCE DEST
#   or:  mv [OPTION]... SOURCE... DIRECTORY
#   or:  mv [OPTION]... -t DIRECTORY SOURCE...
# Rename SOURCE to DEST, or move SOURCE(s) to DIRECTORY.
#
# Mandatory arguments to long options are mandatory for short options too.
#       --backup[=CONTROL]       make a backup of each existing destination file
#   -b                           like --backup but does not accept an argument
#   -f, --force                  do not prompt before overwriting
#   -i, --interactive            prompt before overwrite
#   -n, --no-clobber             do not overwrite an existing file
# If you specify more than one of -i, -f, -n, only the final one takes effect.
#       --strip-trailing-slashes  remove any trailing slashes from each SOURCE
#                                  argument
#   -S, --suffix=SUFFIX          override the usual backup suffix
#   -t, --target-directory=DIRECTORY  move all SOURCE arguments into DIRECTORY
# ...

# %%
# !rm -r /root/mmpretrain/dataset/fruit/test/
# !rm -r /root/mmpretrain/dataset/fruit/val/
# !rm -r  /root/mmpretrain/dataset/fruit/train/

# %%
import os
import random
import shutil
from shutil import copy2
 
def data_take_split(data_folder,take_data_folder,train_scales = 0.8,val_scales = 0.1,test_scales = 0.1 ):
    """
    将源文件分为三个数据集         训练集     验证集     测试集
                                0.8      0.1       0.1
    """
    print('数据集划分开始')
    
    '''
    1.遍历子文件夹
    2.生成对应文件夹
    3.将对应比例的图片复制过去
    '''
 
    subdir_names = os.listdir(data_folder)
    
 
    take_names = ['train','val','test']             #在目标文件夹下创建三个文件夹
    for take_name in take_names:
        take_path = os.path.join(take_data_folder,take_name)
        if os.path.isdir(take_path):
            pass
        else:
            os.mkdir(take_path)
 
 
 
# 按照比列划分数据集，并进行数据图片的复制
 
    train_folder = os.path.join(take_data_folder,'train')       #分割后的训练数据集路径
    val_folder = os.path.join(take_data_folder,'val')           
    test_folder = os.path.join(take_data_folder,'test') 
    
    for subdir_name in subdir_names:
        image_train_path = os.path.join(train_folder,subdir_name);
        image_val_path = os.path.join(val_folder,subdir_name);
        image_test_path = os.path.join(test_folder,subdir_name);
        image_target_path = os.path.join(data_folder,subdir_name)
        picture_names = os.listdir(image_target_path)
        
        current_data_length = len(picture_names)
        current_data_index_list = list(range(current_data_length))
        random.shuffle(current_data_index_list)
        
        train_stop_flage = current_data_length * train_scales
        val_stop_flage = current_data_length * (train_scales + val_scales)
        
        current_index = 0
        train_num = 0
        val_num = 0
        test_num = 0
        
        if os.path.isdir(image_train_path):
            pass
        else:
            os.mkdir(image_train_path)
        if os.path.isdir(image_val_path):
            pass
        else:
            os.mkdir(image_val_path)
        if os.path.isdir(image_test_path):
            pass
        else:
            os.mkdir(image_test_path)
        
        for i in current_data_index_list :
            current_img_path = os.path.join(image_target_path,picture_names[i])
            
            if current_img_path.endswith('.jpg') or current_img_path.endswith('.jpeg') or current_img_path.endswith('.png') or current_img_path.endswith('.JPG'):
                if current_index <= train_stop_flage:
                    copy2(current_img_path,image_train_path)
                    train_num += 1
                elif current_index <= val_stop_flage:
                    copy2(current_img_path,image_val_path)
                    val_num += 1
                else:
                    copy2(current_img_path,image_test_path)
                    test_num += 1

            current_index += 1

        print('训练集', train_num)
        print('验证集', val_num)
        print('测试集', test_num)


if __name__ == '__main__':
    data_folder = '/root/mmpretrain/dataset/fruit'                # 图片源文件地址
    take_data_folder = '/root/mmpretrain/dataset/fruit_data/'           # 图片目标地址
    if os.path.isdir(take_data_folder):
        pass
    else:
        os.mkdir(take_data_folder)
 
    data_take_split(data_folder,take_data_folder)
# Out:
# 数据集划分开始
# 训练集 104
# 验证集 13
# 测试集 12
# 训练集 117
# 验证集 14
# 测试集 14
# 训练集 121
# 验证集 15
# 测试集 14
# 训练集 120
# 验证集 15
# 测试集 14
# 训练集 117
# 验证集 15
# 测试集 14
# 训练集 116
# 验证集 14
# 测试集 14
# 训练集 117
# 验证集 15
# 测试集 14
# 训练集 124
# 验证集 15
# 测试集 15
# 训练集 120
# 验证集 15
# 测试集 14
# 训练集 115
# 验证集 14
# 测试集 14
# 训练集 119
# 验证集 15
# 测试集 14
# 训练集 121
# 验证集 15
# 测试集 15
# 训练集 106
# 验证集 13
# 测试集 13
# 训练集 119
# 验证集 15
# 测试集 14
# 训练集 125
# 验证集 16
# 测试集 15
# 训练集 123
# 验证集 15
# 测试集 15
# 训练集 96
# 验证集 12
# 测试集 11
# 训练集 123
# 验证集 15
# 测试集 15
# 训练集 113
# 验证集 14
# 测试集 13
# 训练集 121
# 验证集 15
# 测试集 15
# 训练集 121
# 验证集 15
# 测试集 14
# 训练集 121
# 验证集 15
# 测试集 15
# 训练集 114
# 验证集 14
# 测试集 14
# 训练集 100
# 验证集 12
# 测试集 12
# 训练集 125
# 验证集 16
# 测试集 15
# 训练集 123
# 验证集 15
# 测试集 15
# 训练集 122
# 验证集 15
# 测试集 15
# 训练集 114
# 验证集 14
# 测试集 14
# 训练集 121
# 验证集 15
# 测试集 15
# 训练集 119
# 验证集 15
# 测试集 14

# %%
# %cd /root/mmpretrain/projects/fruit_fenlei/
# !mim train mmpretrain /root/mmpretrain/projects/fruit_fenlei/ResNet50_fruit.py --work-dir=./exp
# Out:
# [Errno 2] No such file or directory: '/root/mmpretrain/porjects/fruit_fenlei/'
# /root/mmpretrain
# Training command is /opt/conda/bin/python /root/mmpretrain/mmpretrain/.mim/tools/train.py /root/mmpretrain/projects/fruit_fenlei/ResNet50_fruit.py --launcher none --work-dir=./exp.
# 06/07 11:03:44 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.7.6 (default, Jan  8 2020, 19:59:22) [GCC 7.3.0]
#     CUDA available: True
#     numpy_random_seed: 498113963
#     GPU 0: Tesla V100S-PCIE-32GB
#     CUDA_HOME: /usr/local/cuda
#     NVCC: Cuda compilation tools, release 10.1, V10.1.24
#     GCC: gcc (Ubuntu 7.5.0-3ubuntu1~18.04) 7.5.0
#     PyTorch: 1.13.1+cu117
#     PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201402
#   - Intel(R) oneAPI Math Kernel Library Version 2021.4-Product Build 20210904 for Intel(R) 64 architecture applications
# ...

# %%
# !mim test mmpretrain /root/mmpretrain/projects/fruit_fenlei/ResNet50_fruit.py --checkpoint /root/mmpretrain/exp/best_accuracy_top1_epoch_89.pth
# Out:
# Testing command is /opt/conda/bin/python /root/mmpretrain/mmpretrain/.mim/tools/test.py /root/mmpretrain/projects/fruit_fenlei/ResNet50_fruit.py /root/mmpretrain/exp/best_accuracy_top1_epoch_89.pth --launcher none.
# 06/07 12:09:08 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.7.6 (default, Jan  8 2020, 19:59:22) [GCC 7.3.0]
#     CUDA available: True
#     numpy_random_seed: 83137437
#     GPU 0: Tesla V100S-PCIE-32GB
#     CUDA_HOME: /usr/local/cuda
#     NVCC: Cuda compilation tools, release 10.1, V10.1.24
#     GCC: gcc (Ubuntu 7.5.0-3ubuntu1~18.04) 7.5.0
#     PyTorch: 1.13.1+cu117
#     PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201402
#   - Intel(R) oneAPI Math Kernel Library Version 2021.4-Product Build 20210904 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v2.6.0 (Git Hash 52b5f107dd9cf10910aaa19cb47f3abf9b349815)
# ...

# %%
# !mkdir /root/outputs/fruits/
# !mim test mmpretrain /root/mmpretrain/projects/fruit_fenlei/ResNet50_fruit.py --checkpoint /root/mmpretrain/exp/best_accuracy_top1_epoch_89.pth --out /root/outputs/fruits/result.pkl
# Out:
# mkdir: cannot create directory ‘/root/outputs/fruits/’: File exists
# Testing command is /opt/conda/bin/python /root/mmpretrain/mmpretrain/.mim/tools/test.py /root/mmpretrain/projects/fruit_fenlei/ResNet50_fruit.py /root/mmpretrain/exp/best_accuracy_top1_epoch_89.pth --launcher none --out /root/outputs/fruits/result.pkl.
# 06/07 12:10:23 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.7.6 (default, Jan  8 2020, 19:59:22) [GCC 7.3.0]
#     CUDA available: True
#     numpy_random_seed: 1147531036
#     GPU 0: Tesla V100S-PCIE-32GB
#     CUDA_HOME: /usr/local/cuda
#     NVCC: Cuda compilation tools, release 10.1, V10.1.24
#     GCC: gcc (Ubuntu 7.5.0-3ubuntu1~18.04) 7.5.0
#     PyTorch: 1.13.1+cu117
#     PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201402
# ...

# %%
# !mim run mmpretrain analyze_results /root/mmpretrain/projects/fruit_fenlei/ResNet50_fruit.py /root/outputs/fruits/result.pkl --out-dir /root/outputs/fruits/
# Out:
# Use the script /root/mmpretrain/mmpretrain/.mim/tools/analysis_tools/analyze_results.py for command analyze_results.
# The command to call is /opt/conda/bin/python /root/mmpretrain/mmpretrain/.mim/tools/analysis_tools/analyze_results.py /root/mmpretrain/projects/fruit_fenlei/ResNet50_fruit.py /root/outputs/fruits/result.pkl --out-dir /root/outputs/fruits/.
# 06/07 12:11:41 - mmengine - WARNING - `Visualizer` backend is not initialized because save_dir is None.
# /opt/conda/lib/python3.7/site-packages/mmengine/visualization/utils.py:240: UserWarning: Glyph 27060 (\N{CJK UNIFIED IDEOGRAPH-69B4}) missing from current font.
#   s, (width, height) = canvas.print_to_buffer()
# /opt/conda/lib/python3.7/site-packages/mmengine/visualization/utils.py:240: UserWarning: Glyph 33714 (\N{CJK UNIFIED IDEOGRAPH-83B2}) missing from current font.
#   s, (width, height) = canvas.print_to_buffer()
# ...

# %%
# !mim run mmpretrain confusion_matrix  /root/mmpretrain/projects/fruit_fenlei/ResNet50_fruit.py /root/outputs/fruits/result.pkl --show --include-values
# Out:
# Use the script /root/mmpretrain/mmpretrain/.mim/tools/analysis_tools/confusion_matrix.py for command confusion_matrix.
# The command to call is /opt/conda/bin/python /root/mmpretrain/mmpretrain/.mim/tools/analysis_tools/confusion_matrix.py /root/mmpretrain/projects/fruit_fenlei/ResNet50_fruit.py /root/outputs/fruits/result.pkl --show --include-values.
# Figure(1000x1000)
# The script finished successfully.

# %%
# !tree /root/outputs/fruits/success
# Out:
# /bin/bash: tree: command not found

# %%
from mmpretrain import ImageClassificationInferencer
inferencer = ImageClassificationInferencer('.py',pretrained='.pth')
inferencer(".jpg",show=True)
